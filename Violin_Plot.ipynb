# %%
print("New Violin PLot")
# Out:
# New Violin PLot

# %%
import seaborn as sb
import streamlit as st
import pandas as pd

# Get the data
dataframe = pd.read_csv('gapminder_with_codes.csv')
# print(old_dataframe.head())
# print("---------------------------------------------------------------------------")

# Filter by the year
def filtered_by_year(old_dataframe, years):
    of_year = old_dataframe['year'] == year
    dataframe = old_dataframe[of_year]
#     print(dataframe.head())
#     print("---------------------------------------------------------------------------")
    return dataframe
    
#Building the violin plot
def plot(dataframe, x_axis, y_axis):
    sb.violinplot( data = dataframe, x = x_axis, y = y_axis)

plot(filter_by_year(dataframe, 2007), "continent", "lifeExp")
